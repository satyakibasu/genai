# %% [markdown]
# Middleware

# %%
import os
from rich import print
from dotenv import load_dotenv

load_dotenv(override=True)
API_HOST = os.getenv("API_HOST", "github")
API_HOST = "ollama"

from langchain_openai import ChatOpenAI
from langchain_ollama import ChatOllama # --> Do the middleware Human In the Loop test with Ollama as OpenAPI does not work due to security reasons

if API_HOST == "github":
    llm = ChatOpenAI(
            model_name=os.getenv("GITHUB_MODEL", "openai/gpt-4o"),
            openai_api_base="https://models.github.ai/inference",
            openai_api_key=os.environ["GITHUB_TOKEN"],
        )
elif API_HOST == "ollama":
    print("Using Ollama model on local...")
    llm = ChatOllama(model=os.getenv("OLLAMA_MODEL", "mistral"),)
# Out:
# Using Ollama model on local...

# %% [markdown]
# Example - Summarization Middle
# automatically summarizes conversation history when approaching token limit and ..... read langchain docs

# %%
# Create an agent
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langgraph.checkpoint.memory import InMemorySaver
from langchain_core.messages import HumanMessage, SystemMessage

### Messagebased summarization
agent=create_agent(
    model=llm,
    checkpointer=InMemorySaver(),
    middleware=[
        SummarizationMiddleware(
            model=llm,
            trigger=("messages",10),
            keep=("messages",4)
        )
    ]
)

# %%
### Run with thread id
config={"configurable":{"thread_id":"test-1"}}

# %%
questions = [
    "What is 2+2?",
    "What is 10*5?",
    "What is 100/4?",
    "What is 15-7?",
    "What is 3*3?",
    "What is 4*4?",
]

for q in questions:
    response=agent.invoke({"messages":[HumanMessage(content=q)]},config)
    print(f"Messages: {response}")
    print(f"Messages: {len(response['messages'])}")
# Out:
# Messages: {'messages': [HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={},
# id='bc63c9fe-0a0f-4d36-a67a-0858a339f82c'), AIMessage(content=' The sum of 2 and 2 is 4.', additional_kwargs={},
# response_metadata={'model': 'mistral', 'created_at': '2026-01-02T04:49:57.286776Z', 'done': True, 'done_reason':
# 'stop', 'total_duration': 10467098708, 'load_duration': 3408066042, 'prompt_eval_count': 11,
# 'prompt_eval_duration': 4557490916, 'eval_count': 13, 'eval_duration': 2438295335, 'logprobs': None, 'model_name':
# 'mistral', 'model_provider': 'ollama'}, id='lc_run--019b7d0a-5138-72b3-a90a-a1d9467ffb74-0',
# usage_metadata={'input_tokens': 11, 'output_tokens': 13, 'total_tokens': 24})]}
# Messages: 2
# Messages: {'messages': [HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={},
# id='bc63c9fe-0a0f-4d36-a67a-0858a339f82c'), AIMessage(content=' The sum of 2 and 2 is 4.', additional_kwargs={},
# response_metadata={'model': 'mistral', 'created_at': '2026-01-02T04:49:57.286776Z', 'done': True, 'done_reason':
# 'stop', 'total_duration': 10467098708, 'load_duration': 3408066042, 'prompt_eval_count': 11,
# 'prompt_eval_duration': 4557490916, 'eval_count': 13, 'eval_duration': 2438295335, 'logprobs': None, 'model_name':
# 'mistral', 'model_provider': 'ollama'}, id='lc_run--019b7d0a-5138-72b3-a90a-a1d9467ffb74-0',
# usage_metadata={'input_tokens': 11, 'output_tokens': 13, 'total_tokens': 24}), HumanMessage(content='What is
# 10*5?', additional_kwargs={}, response_metadata={}, id='057de612-5b96-4c92-aa46-f263e6b3f173'), AIMessage(content='
# The product of 10 and 5 is 50.', additional_kwargs={}, response_metadata={'model': 'mistral', 'created_at':
# '2026-01-02T04:50:02.923412Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5518900334, 'load_duration':
# 37392167, 'prompt_eval_count': 36, 'prompt_eval_duration': 2170841167, 'eval_count': 15, 'eval_duration':
# 3227531001, 'logprobs': None, 'model_name': 'mistral', 'model_provider': 'ollama'},
# id='lc_run--019b7d0a-7a95-7703-bb90-1321a62cfb37-0', usage_metadata={'input_tokens': 36, 'output_tokens': 15,
# 'total_tokens': 51})]}
# Messages: 4
# Messages: {'messages': [HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={},
# id='bc63c9fe-0a0f-4d36-a67a-0858a339f82c'), AIMessage(content=' The sum of 2 and 2 is 4.', additional_kwargs={},
# response_metadata={'model': 'mistral', 'created_at': '2026-01-02T04:49:57.286776Z', 'done': True, 'done_reason':
# 'stop', 'total_duration': 10467098708, 'load_duration': 3408066042, 'prompt_eval_count': 11,
# 'prompt_eval_duration': 4557490916, 'eval_count': 13, 'eval_duration': 2438295335, 'logprobs': None, 'model_name':
# 'mistral', 'model_provider': 'ollama'}, id='lc_run--019b7d0a-5138-72b3-a90a-a1d9467ffb74-0',
# usage_metadata={'input_tokens': 11, 'output_tokens': 13, 'total_tokens': 24}), HumanMessage(content='What is
# 10*5?', additional_kwargs={}, response_metadata={}, id='057de612-5b96-4c92-aa46-f263e6b3f173'), AIMessage(content='
# The product of 10 and 5 is 50.', additional_kwargs={}, response_metadata={'model': 'mistral', 'created_at':
# '2026-01-02T04:50:02.923412Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5518900334, 'load_duration':
# 37392167, 'prompt_eval_count': 36, 'prompt_eval_duration': 2170841167, 'eval_count': 15, 'eval_duration':
# 3227531001, 'logprobs': None, 'model_name': 'mistral', 'model_provider': 'ollama'},
# id='lc_run--019b7d0a-7a95-7703-bb90-1321a62cfb37-0', usage_metadata={'input_tokens': 36, 'output_tokens': 15,
# 'total_tokens': 51}), HumanMessage(content='What is 100/4?', additional_kwargs={}, response_metadata={},
# id='f65b0ad7-03e7-46fd-b3e2-5360a5d2be5a'), AIMessage(content='  The quotient of 100 divided by 4 is 25. If you
# want the decimal form, it would be 25.0 (with a decimal point and no trailing zeros).', additional_kwargs={},
# response_metadata={'model': 'mistral', 'created_at': '2026-01-02T04:50:12.739696Z', 'done': True, 'done_reason':
# 'stop', 'total_duration': 9734457292, 'load_duration': 36288875, 'prompt_eval_count': 64, 'prompt_eval_duration':
# 2765660500, 'eval_count': 45, 'eval_duration': 6820531710, 'logprobs': None, 'model_name': 'mistral',
# 'model_provider': 'ollama'}, id='lc_run--019b7d0a-9075-7981-84c4-11ecf29c069c-0', usage_metadata={'input_tokens':
# 64, 'output_tokens': 45, 'total_tokens': 109})]}
# Messages: 6
# Messages: {'messages': [HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={},
# id='bc63c9fe-0a0f-4d36-a67a-0858a339f82c'), AIMessage(content=' The sum of 2 and 2 is 4.', additional_kwargs={},
# response_metadata={'model': 'mistral', 'created_at': '2026-01-02T04:49:57.286776Z', 'done': True, 'done_reason':
# 'stop', 'total_duration': 10467098708, 'load_duration': 3408066042, 'prompt_eval_count': 11,
# 'prompt_eval_duration': 4557490916, 'eval_count': 13, 'eval_duration': 2438295335, 'logprobs': None, 'model_name':
# 'mistral', 'model_provider': 'ollama'}, id='lc_run--019b7d0a-5138-72b3-a90a-a1d9467ffb74-0',
# usage_metadata={'input_tokens': 11, 'output_tokens': 13, 'total_tokens': 24}), HumanMessage(content='What is
# 10*5?', additional_kwargs={}, response_metadata={}, id='057de612-5b96-4c92-aa46-f263e6b3f173'), AIMessage(content='
# The product of 10 and 5 is 50.', additional_kwargs={}, response_metadata={'model': 'mistral', 'created_at':
# '2026-01-02T04:50:02.923412Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5518900334, 'load_duration':
# 37392167, 'prompt_eval_count': 36, 'prompt_eval_duration': 2170841167, 'eval_count': 15, 'eval_duration':
# 3227531001, 'logprobs': None, 'model_name': 'mistral', 'model_provider': 'ollama'},
# id='lc_run--019b7d0a-7a95-7703-bb90-1321a62cfb37-0', usage_metadata={'input_tokens': 36, 'output_tokens': 15,
# 'total_tokens': 51}), HumanMessage(content='What is 100/4?', additional_kwargs={}, response_metadata={},
# id='f65b0ad7-03e7-46fd-b3e2-5360a5d2be5a'), AIMessage(content='  The quotient of 100 divided by 4 is 25. If you
# want the decimal form, it would be 25.0 (with a decimal point and no trailing zeros).', additional_kwargs={},
# response_metadata={'model': 'mistral', 'created_at': '2026-01-02T04:50:12.739696Z', 'done': True, 'done_reason':
# 'stop', 'total_duration': 9734457292, 'load_duration': 36288875, 'prompt_eval_count': 64, 'prompt_eval_duration':
# 2765660500, 'eval_count': 45, 'eval_duration': 6820531710, 'logprobs': None, 'model_name': 'mistral',
# 'model_provider': 'ollama'}, id='lc_run--019b7d0a-9075-7981-84c4-11ecf29c069c-0', usage_metadata={'input_tokens':
# 64, 'output_tokens': 45, 'total_tokens': 109}), HumanMessage(content='What is 15-7?', additional_kwargs={},
# response_metadata={}, id='f8897042-16c6-4d77-bad7-dbfc26cde57e'), AIMessage(content='  The difference between 15
# and 7 is 8.', additional_kwargs={}, response_metadata={'model': 'mistral', 'created_at':
# '2026-01-02T04:50:17.398471Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4567766459, 'load_duration':
# 49530584, 'prompt_eval_count': 120, 'prompt_eval_duration': 2055129833, 'eval_count': 15, 'eval_duration':
# 2400795957, 'logprobs': None, 'model_name': 'mistral', 'model_provider': 'ollama'},
# id='lc_run--019b7d0a-b6d6-7961-aaef-a72c51fbc31c-0', usage_metadata={'input_tokens': 120, 'output_tokens': 15,
# 'total_tokens': 135})]}
# Messages: 8
# Messages: {'messages': [HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={},
# id='bc63c9fe-0a0f-4d36-a67a-0858a339f82c'), AIMessage(content=' The sum of 2 and 2 is 4.', additional_kwargs={},
# response_metadata={'model': 'mistral', 'created_at': '2026-01-02T04:49:57.286776Z', 'done': True, 'done_reason':
# 'stop', 'total_duration': 10467098708, 'load_duration': 3408066042, 'prompt_eval_count': 11,
# 'prompt_eval_duration': 4557490916, 'eval_count': 13, 'eval_duration': 2438295335, 'logprobs': None, 'model_name':
# 'mistral', 'model_provider': 'ollama'}, id='lc_run--019b7d0a-5138-72b3-a90a-a1d9467ffb74-0',
# usage_metadata={'input_tokens': 11, 'output_tokens': 13, 'total_tokens': 24}), HumanMessage(content='What is
# 10*5?', additional_kwargs={}, response_metadata={}, id='057de612-5b96-4c92-aa46-f263e6b3f173'), AIMessage(content='
# The product of 10 and 5 is 50.', additional_kwargs={}, response_metadata={'model': 'mistral', 'created_at':
# '2026-01-02T04:50:02.923412Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5518900334, 'load_duration':
# 37392167, 'prompt_eval_count': 36, 'prompt_eval_duration': 2170841167, 'eval_count': 15, 'eval_duration':
# 3227531001, 'logprobs': None, 'model_name': 'mistral', 'model_provider': 'ollama'},
# id='lc_run--019b7d0a-7a95-7703-bb90-1321a62cfb37-0', usage_metadata={'input_tokens': 36, 'output_tokens': 15,
# 'total_tokens': 51}), HumanMessage(content='What is 100/4?', additional_kwargs={}, response_metadata={},
# id='f65b0ad7-03e7-46fd-b3e2-5360a5d2be5a'), AIMessage(content='  The quotient of 100 divided by 4 is 25. If you
# want the decimal form, it would be 25.0 (with a decimal point and no trailing zeros).', additional_kwargs={},
# response_metadata={'model': 'mistral', 'created_at': '2026-01-02T04:50:12.739696Z', 'done': True, 'done_reason':
# 'stop', 'total_duration': 9734457292, 'load_duration': 36288875, 'prompt_eval_count': 64, 'prompt_eval_duration':
# 2765660500, 'eval_count': 45, 'eval_duration': 6820531710, 'logprobs': None, 'model_name': 'mistral',
# 'model_provider': 'ollama'}, id='lc_run--019b7d0a-9075-7981-84c4-11ecf29c069c-0', usage_metadata={'input_tokens':
# 64, 'output_tokens': 45, 'total_tokens': 109}), HumanMessage(content='What is 15-7?', additional_kwargs={},
# response_metadata={}, id='f8897042-16c6-4d77-bad7-dbfc26cde57e'), AIMessage(content='  The difference between 15
# and 7 is 8.', additional_kwargs={}, response_metadata={'model': 'mistral', 'created_at':
# '2026-01-02T04:50:17.398471Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4567766459, 'load_duration':
# 49530584, 'prompt_eval_count': 120, 'prompt_eval_duration': 2055129833, 'eval_count': 15, 'eval_duration':
# 2400795957, 'logprobs': None, 'model_name': 'mistral', 'model_provider': 'ollama'},
# id='lc_run--019b7d0a-b6d6-7961-aaef-a72c51fbc31c-0', usage_metadata={'input_tokens': 120, 'output_tokens': 15,
# 'total_tokens': 135}), HumanMessage(content='What is 3*3?', additional_kwargs={}, response_metadata={},
# id='bb7a881e-89e8-466b-aa11-537d96faf225'), AIMessage(content='   The product of 3 and 3 is 9.',
# additional_kwargs={}, response_metadata={'model': 'mistral', 'created_at': '2026-01-02T04:50:21.867524Z', 'done':
# True, 'done_reason': 'stop', 'total_duration': 4337277750, 'load_duration': 55896583, 'prompt_eval_count': 145,
# 'prompt_eval_duration': 2050170250, 'eval_count': 14, 'eval_duration': 2162892914, 'logprobs': None, 'model_name':
# 'mistral', 'model_provider': 'ollama'}, id='lc_run--019b7d0a-c923-75d2-b561-80b639209132-0',
# usage_metadata={'input_tokens': 145, 'output_tokens': 14, 'total_tokens': 159})]}
# Messages: 10
# Messages: {'messages': [HumanMessage(content='Here is a summary of the conversation to date:\n\nThe context to be
# extracted from the conversation history is:\n\n1. The sum of 2 and 2 is 4.\n2. The product of 10 and 5 is 50.\n3.
# The quotient of 100 divided by 4 is 25.\n4. The result of 15-7 is not provided in the conversation history.',
# additional_kwargs={}, response_metadata={}, id='f907b503-f7fa-4f89-be66-d6ddf31cbe13'), AIMessage(content='  The
# difference between 15 and 7 is 8.', additional_kwargs={}, response_metadata={'model': 'mistral', 'created_at':
# '2026-01-02T04:50:17.398471Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4567766459, 'load_duration':
# 49530584, 'prompt_eval_count': 120, 'prompt_eval_duration': 2055129833, 'eval_count': 15, 'eval_duration':
# 2400795957, 'logprobs': None, 'model_name': 'mistral', 'model_provider': 'ollama'},
# id='lc_run--019b7d0a-b6d6-7961-aaef-a72c51fbc31c-0', usage_metadata={'input_tokens': 120, 'output_tokens': 15,
# 'total_tokens': 135}), HumanMessage(content='What is 3*3?', additional_kwargs={}, response_metadata={},
# id='bb7a881e-89e8-466b-aa11-537d96faf225'), AIMessage(content='   The product of 3 and 3 is 9.',
# additional_kwargs={}, response_metadata={'model': 'mistral', 'created_at': '2026-01-02T04:50:21.867524Z', 'done':
# True, 'done_reason': 'stop', 'total_duration': 4337277750, 'load_duration': 55896583, 'prompt_eval_count': 145,
# 'prompt_eval_duration': 2050170250, 'eval_count': 14, 'eval_duration': 2162892914, 'logprobs': None, 'model_name':
# 'mistral', 'model_provider': 'ollama'}, id='lc_run--019b7d0a-c923-75d2-b561-80b639209132-0',
# usage_metadata={'input_tokens': 145, 'output_tokens': 14, 'total_tokens': 159}), HumanMessage(content='What is
# 4*4?', additional_kwargs={}, response_metadata={}, id='ff83f7f2-b6e1-4f87-b664-608c5dbc5c38'), AIMessage(content='
# The product of 4 and 4 is 16.', additional_kwargs={}, response_metadata={'model': 'mistral', 'created_at':
# '2026-01-02T04:51:16.320364Z', 'done': True, 'done_reason': 'stop', 'total_duration': 9768612125, 'load_duration':
# 101152708, 'prompt_eval_count': 148, 'prompt_eval_duration': 4048963500, 'eval_count': 15, 'eval_duration':
# 5379759460, 'logprobs': None, 'model_name': 'mistral', 'model_provider': 'ollama'},
# id='lc_run--019b7d0b-8880-72f3-9861-1715b9c53c4d-0', usage_metadata={'input_tokens': 148, 'output_tokens': 15,
# 'total_tokens': 163})]}
# Messages: 6

# %% [markdown]
# Using Token count

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
from langgraph.checkpoint.memory import InMemorySaver

@tool
def search_hotels(city: str) -> str:
    """Search hotels - returns long response to use more tokens."""
    return f"""Hotels in {city}:
    1. Grand Hotel - 5 star, $350/night, spa, pool, gym
    2. City Inn - 4 star, $180/night, business center
    3. Budget Stay - 3 star, $75/night, free wifi"""


agent=create_agent(
    model=llm,
    checkpointer=InMemorySaver(),
    middleware=[
            SummarizationMiddleware(
                                    model=llm,
                                    trigger=("tokens",550),
                                    keep=("tokens",200)
                                    )
                ],
    tools=[search_hotels]
)

config = {"configurable":{"thread_id":"test_1"}}

# Token counter (approximate)
def count_tokens(messages):
    total_chars = sum(len(str(m.content)) for m in messages)
    return total_chars // 4  # 4 chars ≈ 1 token

# %%
# Run test
cities = ["Paris", "London", "Tokyo", "New York", "Dubai", "Singapore"]

for city in cities:
    response = agent.invoke(
        {"messages": [HumanMessage(content=f"Find hotels in {city}")]},
        config=config
    )
    
    tokens = count_tokens(response["messages"])
    print(f"{city}: ~{tokens} tokens, {len(response['messages'])} messages")
    print(f"{(response['messages'])}")

# %% [markdown]
# Human in the Loop

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import HumanInTheLoopMiddleware
from langgraph.checkpoint.memory import InMemorySaver

def read_email_tool(email_id: str) -> str:
    """Mock function to read an email by its ID."""
    return f"Email content for ID: {email_id}"

def send_email_tool(recipient: str, subject: str, body: str) -> str:
    """Mock function to send an email."""
    return f"Email sent to {recipient} with subject '{subject}'"

# %%
agent=create_agent(
    model=llm,
    tools=[read_email_tool,send_email_tool],
    checkpointer=InMemorySaver(),
    middleware=[
        HumanInTheLoopMiddleware(
            interrupt_on={
                "send_email_tool":{
                    "allowed_decisions":["approve","edit","reject"]
                },
                "read_email_tool":False,

            }
        )
    ]
)

# %%
config = {"configurable": {"thread_id": "test-approve"}}
# Step 1: Request
result = agent.invoke({"messages": [HumanMessage(content="Send email to john@test.com with subject 'Hello' and body 'How are you?'")]},
    config=config
)

# %%
result
# Out:
# {'messages': [HumanMessage(content="Send email to john@test.com with subject 'Hello' and body 'How are you?'", additional_kwargs={}, response_metadata={}, id='4c584b01-4b6d-43a8-ba94-2a43e933407b'),
#   AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'mistral', 'created_at': '2026-01-02T04:53:09.722117Z', 'done': True, 'done_reason': 'stop', 'total_duration': 18730647291, 'load_duration': 41483041, 'prompt_eval_count': 164, 'prompt_eval_duration': 5352621792, 'eval_count': 87, 'eval_duration': 13159857080, 'logprobs': None, 'model_name': 'mistral', 'model_provider': 'ollama'}, id='lc_run--019b7d0d-20a4-7892-aab9-58a78613c837-0', tool_calls=[{'name': 'send_email_tool', 'args': {'body': 'How are you?', 'recipient': 'john@test.com', 'subject': 'Hello'}, 'id': '9c6dee16-2119-489b-9333-18f4c5bef2aa', 'type': 'tool_call'}], usage_metadata={'input_tokens': 164, 'output_tokens': 87, 'total_tokens': 251})],
#  '__interrupt__': [Interrupt(value={'action_requests': [{'name': 'send_email_tool', 'args': {'body': 'How are you?', 'recipient': 'john@test.com', 'subject': 'Hello'}, 'description': "Tool execution requires approval\n\nTool: send_email_tool\nArgs: {'body': 'How are you?', 'recipient': 'john@test.com', 'subject': 'Hello'}"}], 'review_configs': [{'action_name': 'send_email_tool', 'allowed_decisions': ['approve', 'edit', 'reject']}]}, id='2b11736e5114b5f354667be8e3322eb0')]}

# %% [markdown]
# Approve

# %%
from langgraph.types import Command

# Step 2: Approve
if "__interrupt__" in result:
    print("⏸️ Paused! Approving...")
    
    result = agent.invoke(
        Command(
            resume={
                "decisions": [
                    {"type": "approve"}
                ]
            }
        ),
        config=config
    )
    
    print(f"✅ Result: {result['messages'][-1].content}")
# Out:
# ⏸️ Paused! Approving...
# ✅ Result:  Email has been successfully sent to john@test.com with the subject 'Hello'.

# %%
result
# Out:
# {'messages': [HumanMessage(content="Send email to john@test.com with subject 'Hello' and body 'How are you?'", additional_kwargs={}, response_metadata={}, id='4c584b01-4b6d-43a8-ba94-2a43e933407b'),
#   AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'mistral', 'created_at': '2026-01-02T04:53:09.722117Z', 'done': True, 'done_reason': 'stop', 'total_duration': 18730647291, 'load_duration': 41483041, 'prompt_eval_count': 164, 'prompt_eval_duration': 5352621792, 'eval_count': 87, 'eval_duration': 13159857080, 'logprobs': None, 'model_name': 'mistral', 'model_provider': 'ollama'}, id='lc_run--019b7d0d-20a4-7892-aab9-58a78613c837-0', tool_calls=[{'name': 'send_email_tool', 'args': {'body': 'How are you?', 'recipient': 'john@test.com', 'subject': 'Hello'}, 'id': '9c6dee16-2119-489b-9333-18f4c5bef2aa', 'type': 'tool_call'}], usage_metadata={'input_tokens': 164, 'output_tokens': 87, 'total_tokens': 251}),
#   ToolMessage(content="Email sent to john@test.com with subject 'Hello'", name='send_email_tool', id='ce206fe8-d91c-420a-bdd6-4ed15f0e4688', tool_call_id='9c6dee16-2119-489b-9333-18f4c5bef2aa'),
#   AIMessage(content=" Email has been successfully sent to john@test.com with the subject 'Hello'.", additional_kwargs={}, response_metadata={'model': 'mistral', 'created_at': '2026-01-02T04:54:46.386166Z', 'done': True, 'done_reason': 'stop', 'total_duration': 7059083167, 'load_duration': 45735125, 'prompt_eval_count': 88, 'prompt_eval_duration': 3953146958, 'eval_count': 19, 'eval_duration': 2989876709, 'logprobs': None, 'model_name': 'mistral', 'model_provider': 'ollama'}, id='lc_run--019b7d0e-c7d5-7f43-b4c6-d980411b85a1-0', usage_metadata={'input_tokens': 88, 'output_tokens': 19, 'total_tokens': 107})]}

# %% [markdown]
# Reject

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import HumanInTheLoopMiddleware
from langgraph.checkpoint.memory import InMemorySaver


def read_email_tool(email_id: str) -> str:
    """Mock function to read an email by its ID."""
    return f"Email content for ID: {email_id}"

def send_email_tool(recipient: str, subject: str, body: str) -> str:
    """Mock function to send an email."""
    return f"Email sent to {recipient} with subject '{subject}'"

agent = create_agent(
    model=llm,
    tools=[read_email_tool,send_email_tool],
    checkpointer=InMemorySaver(),
    middleware=[
        HumanInTheLoopMiddleware(
            interrupt_on={
                "send_email_tool": {
                    "allowed_decisions": ["approve", "edit", "reject"],
                },
                "read_email_tool": False,
            }
        ),
    ],
)

# %%
config = {"configurable": {"thread_id": "test-reject"}}

# Step 1: Request
result = agent.invoke(
    {"messages": [HumanMessage(content="Send email to john@test.com with subject 'Hello' and body 'How are you?'")]},
    config=config)
result
# Out:
# {'messages': [HumanMessage(content="Send email to john@test.com with subject 'Hello' and body 'How are you?'", additional_kwargs={}, response_metadata={}, id='bcd480f4-8af0-4726-a32e-e6315b2d1b9e'),
#   AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'mistral', 'created_at': '2026-01-02T04:59:12.664792Z', 'done': True, 'done_reason': 'stop', 'total_duration': 25157304209, 'load_duration': 34945125, 'prompt_eval_count': 164, 'prompt_eval_duration': 4848674625, 'eval_count': 80, 'eval_duration': 19964323332, 'logprobs': None, 'model_name': 'mistral', 'model_provider': 'ollama'}, id='lc_run--019b7d12-914d-7542-84dd-1b96f14fe2a3-0', tool_calls=[{'name': 'send_email_tool', 'args': {'body': 'How are you?', 'recipient': 'john@test.com', 'subject': 'Hello'}, 'id': '6a99acce-3da2-48ae-8790-181c1c829438', 'type': 'tool_call'}], usage_metadata={'input_tokens': 164, 'output_tokens': 80, 'total_tokens': 244})],
#  '__interrupt__': [Interrupt(value={'action_requests': [{'name': 'send_email_tool', 'args': {'body': 'How are you?', 'recipient': 'john@test.com', 'subject': 'Hello'}, 'description': "Tool execution requires approval\n\nTool: send_email_tool\nArgs: {'body': 'How are you?', 'recipient': 'john@test.com', 'subject': 'Hello'}"}], 'review_configs': [{'action_name': 'send_email_tool', 'allowed_decisions': ['approve', 'edit', 'reject']}]}, id='ecc5727926d0b5afff5e602344c1a2b2')]}

# %%
# Step 2: Reject

if "__interrupt__" in result:
    print("⏸️ Paused! Approving...")
    
    result = agent.invoke(
        Command(
            resume={
                "decisions": [
                    {"type": "reject"}
                ]
            }
        ),
        config=config
    )
    
    print(f"✅ Result: {result['messages'][-1].content}")
# Out:
# ⏸️ Paused! Approving...
# ✅ Result:  It seems that the email could not be sent due to user rejection of the tool call. You might want to
# check if the tool is properly configured or if the user has granted permission to send emails from this tool.

# %% [markdown]
# Editing

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import HumanInTheLoopMiddleware
from langgraph.checkpoint.memory import InMemorySaver


def read_email_tool(email_id: str) -> str:
    """Mock function to read an email by its ID."""
    return f"Email content for ID: {email_id}"

def send_email_tool(recipient: str, subject: str, body: str) -> str:
    """Mock function to send an email."""
    return f"Email sent to {recipient} with subject '{subject}'"

agent = create_agent(
    model=llm,
    tools=[read_email_tool,send_email_tool],
    checkpointer=InMemorySaver(),
    middleware=[
        HumanInTheLoopMiddleware(
            interrupt_on={
                "send_email_tool": {
                    "allowed_decisions": ["approve", "edit", "reject"],
                },
                "read_email_tool": False,
            }
        ),
    ],
)

# %%
config = {"configurable": {"thread_id": "test-edit"}}

# Step 1: Request (with wrong info)
result = agent.invoke(
    {"messages": [HumanMessage(content="Send email to wrong@email.com with subject 'Test' and body 'Hello'")]},
    config=config
)

print(result)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content="Send email to wrong@email.com with subject 'Test' and body 'Hello'",
#             additional_kwargs={},
#             response_metadata={},
#             id='692da7f3-96b0-4c5c-9bf0-baf8b064e0d1'
#         ),
#         AIMessage(
#             content='',
#             additional_kwargs={},
#             response_metadata={
#                 'model': 'mistral',
#                 'created_at': '2026-01-02T05:01:06.138937Z',
#                 'done': True,
#                 'done_reason': 'stop',
#                 'total_duration': 21462564708,
#                 'load_duration': 38520791,
#                 'prompt_eval_count': 161,
#                 'prompt_eval_duration': 4504777292,
#                 'eval_count': 82,
#                 'eval_duration': 16535194377,
#                 'logprobs': None,
#                 'model_name': 'mistral',
#                 'model_provider': 'ollama'
#             },
#             id='lc_run--019b7d14-5af2-7832-87c8-f18ea81e27f6-0',
#             tool_calls=[
#                 {
#                     'name': 'send_email_tool',
#                     'args': {'body': 'Hello', 'recipient': 'wrong@email.com', 'subject': 'Test'},
#                     'id': 'e24989f0-0a1a-4c38-bc42-4a91326c7de2',
#                     'type': 'tool_call'
#                 }
#             ],
#             usage_metadata={'input_tokens': 161, 'output_tokens': 82, 'total_tokens': 243}
#         ),
#         HumanMessage(
#             content="Send email to wrong@email.com with subject 'Test' and body 'Hello'",
#             additional_kwargs={},
#             response_metadata={},
#             id='154e8281-8c0e-4870-bebb-0888110720b5'
#         ),
#         AIMessage(
#             content='',
#             additional_kwargs={},
#             response_metadata={
#                 'model': 'mistral',
#                 'created_at': '2026-01-02T05:01:39.765331Z',
#                 'done': True,
#                 'done_reason': 'stop',
#                 'total_duration': 11778977875,
#                 'load_duration': 54011250,
#                 'prompt_eval_count': 221,
#                 'prompt_eval_duration': 4542989583,
#                 'eval_count': 43,
#                 'eval_duration': 7046453085,
#                 'logprobs': None,
#                 'model_name': 'mistral',
#                 'model_provider': 'ollama'
#             },
#             id='lc_run--019b7d15-041b-7e23-a2af-8866adba22f8-0',
#             tool_calls=[
#                 {
#                     'name': 'send_email_tool',
#                     'args': {'body': 'Hello', 'recipient': 'wrong@email.com', 'subject': 'Test'},
#                     'id': '2e8fcdea-3bc6-4427-bac0-35e268268f0c',
#                     'type': 'tool_call'
#                 }
#             ],
#             usage_metadata={'input_tokens': 221, 'output_tokens': 43, 'total_tokens': 264}
#         )
#     ],
#     '__interrupt__': [
#         Interrupt(
#             value={
#                 'action_requests': [
#                     {
#                         'name': 'send_email_tool',
#                         'args': {'body': 'Hello', 'recipient': 'wrong@email.com', 'subject': 'Test'},
#                         'description': "Tool execution requires approval\n\nTool: send_email_tool\nArgs: {'body':
# 'Hello', 'recipient': 'wrong@email.com', 'subject': 'Test'}"
#                     }
#                 ],
#                 'review_configs': [
#                     {'action_name': 'send_email_tool', 'allowed_decisions': ['approve', 'edit', 'reject']}
#                 ]
#             },
#             id='d9ee460f4b0ef505656f4fa2cc76c13b'
#         )
#     ]
# }

# %%
# Step 2: Edit and approve

if "__interrupt__" in result:
    print("⏸️ Paused! Editing...")
    
    result = agent.invoke(
        Command(
            resume={
                "decisions": [
                    {
                        "type": "edit",
                        "edited_action": {
                            "name": "send_email_tool",      # Tool name
                            "args": {                   # New arguments
                                "recipient": "correct@email.com",
                                "subject": "Corrected Subject",
                                "body": "This was edited by human before sending"
                            }
                        }
                    }
                ]
            }
        ),
        config=config
    )
    
    print(f"✏️ Result: {result['messages'][-1].content}")
# Out:
# ⏸️ Paused! Editing...
# ✏️ Result:  I have corrected the email content as you requested. The updated message is:
#
# [{"name": "send_email_tool", "arguments": {"body":"This was edited by human before
# sending","recipient":"correct@email.com","subject":"Corrected Subject"}}]
