# %%
sentence="The Eiffel Tower was built from 1887 to 1889 by French engineer Gustave Eiffel, whose company specialized in building metal frameworks and structures."

# %%
import nltk
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
words = nltk.word_tokenize(sentence)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /Users/satyakibasu/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/satyakibasu/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.

# %%
pos_tags = nltk.pos_tag(words)
pos_tags
# Out:
# [('The', 'DT'),
#  ('Eiffel', 'NNP'),
#  ('Tower', 'NNP'),
#  ('was', 'VBD'),
#  ('built', 'VBN'),
#  ('from', 'IN'),
#  ('1887', 'CD'),
#  ('to', 'TO'),
#  ('1889', 'CD'),
#  ('by', 'IN'),
#  ('French', 'JJ'),
#  ('engineer', 'NN'),
#  ('Gustave', 'NNP'),
#  ('Eiffel', 'NNP'),
#  (',', ','),
#  ('whose', 'WP$'),
#  ('company', 'NN'),
#  ('specialized', 'VBD'),
#  ('in', 'IN'),
#  ('building', 'NN'),
#  ('metal', 'NN'),
#  ('frameworks', 'NNS'),
#  ('and', 'CC'),
#  ('structures', 'NNS'),
#  ('.', '.')]

# %%
nltk.ne_chunk(pos_tags).draw() #please install Tkinter library)
# Out:
# /Users/satyakibasu/Documents/Satyaki/python_code/gen-ai/p311env/lib/python3.11/site-packages/nltk/draw/__init__.py:15: UserWarning: nltk.draw package not loaded (please install Tkinter library).
#   warnings.warn("nltk.draw package not loaded (please install Tkinter library).")
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 nltk.ne_chunk(pos_tags).draw()
#
# File ~/Documents/Satyaki/python_code/gen-ai/p311env/lib/python3.11/site-packages/nltk/tree/tree.py:759, in Tree.draw(self)
#     755 def draw(self):
#     756     """
#     757     Open a new window containing a graphical diagram of this tree.
#     758     """
# --> 759     from nltk.draw.tree import draw_trees
#     761     draw_trees(self)
#
# File ~/Documents/Satyaki/python_code/gen-ai/p311env/lib/python3.11/site-packages/nltk/draw/tree.py:12
#       1 # Natural Language Toolkit: Graphical Representations for Trees
#       2 #
#       3 # Copyright (C) 2001-2025 NLTK Project
#       4 # Author: Edward Loper <edloper@gmail.com>
#       5 # URL: <https://www.nltk.org/>
#       6 # For license information, see LICENSE.TXT
#       8 """
#       9 Graphically display a Tree.
#      10 """
# ---> 12 from tkinter import IntVar, Menu, Tk
#      14 from nltk.draw.util import (
#      15     BoxWidget,
#      16     CanvasFrame,
#    (...)     20     TextWidget,
#      21 )
#      22 from nltk.tree import Tree
#
# File /opt/homebrew/Cellar/python@3.11/3.11.14_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/tkinter/__init__.py:38
#      35 import sys
#      36 import types
# ---> 38 import _tkinter # If this fails your Python may not be configured for Tk
#      39 TclError = _tkinter.TclError
#      40 from tkinter.constants import *
#
# ModuleNotFoundError: No module named '_tkinter'
