# %%
corpus = "Hello, world! This is a sample corpus for tokenization. This is a test. Tokenization is fun."

# %%
corpus
# Out:
# 'Hello, world! This is a sample corpus for tokenization. This is a test. Tokenization is fun.'

# %%
# Tokenization using NLTK
# Convert a paragraph (corpus) to sentences (documents)
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize, sent_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/satyakibasu/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
sentences = sent_tokenize(corpus)
sentences
# Out:
# ['Hello, world!',
#  'This is a sample corpus for tokenization.',
#  'This is a test.',
#  'Tokenization is fun.']

# %%
#Paragraph to words (tokens)
words = word_tokenize(corpus)
words
# Out:
# ['Hello',
#  ',',
#  'world',
#  '!',
#  'This',
#  'is',
#  'a',
#  'sample',
#  'corpus',
#  'for',
#  'tokenization',
#  '.',
#  'This',
#  'is',
#  'a',
#  'test',
#  '.',
#  'Tokenization',
#  'is',
#  'fun',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokens = tokenizer.tokenize(corpus)
tokens
# Out:
# ['Hello',
#  ',',
#  'world',
#  '!',
#  'This',
#  'is',
#  'a',
#  'sample',
#  'corpus',
#  'for',
#  'tokenization.',
#  'This',
#  'is',
#  'a',
#  'test.',
#  'Tokenization',
#  'is',
#  'fun',
#  '.']
